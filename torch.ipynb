# %% [markdown]
# [Transformers + Classifier Method Starter [Train]](https://www.kaggle.com/manabendrarout/transformers-classifier-method-starter-train#Problem-Statement)

# %% [markdown]
# # Installations

# %%
! pip install -qq timm
! pip install -qq albumentations
! pip install -qq grad-cam
! pip install -qq ttach

# %% [markdown]
# # Imports

# %%
# Aesthetics
import warnings
import sklearn.exceptions

# General
from tqdm.auto import tqdm
from collections import defaultdict
import pandas as pd
import numpy as np
import os
import random
import gc
import cv2
import glob
gc.enable()
pd.set_option('display.max_columns', None)

# Visualization
import matplotlib.pyplot as plt
# % matplotlib inline

# Image Aug
import albumentations
from albumentations.pytorch.transforms import ToTensor

# Deep Learning
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts, OneCycleLR, CosineAnnealingLR
import torch
import torchvision
import timm
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# Metrics
from sklearn.metrics import mean_squared_error

# Random Seed Initialize
RANDOM_SEED = 42

def seed_everything(seed=RANDOM_SEED):
    os.environ['PYTHONHASHSEED']=str(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic=True
    torch.backends.cudnn.benchmark=True

seed_everything()

# Device Optimization

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
    
print(f'Using device: {device}')
# Out:
# Using device: cpu

# %%
csv_dir = './input/pertfinder-pawpularity-score'
train_dir = './input/pertfinder-pawpularity-score/train'
test_dir = './input/pertfinder-pawpularity-score/test'

train_file_path = './input/pawpular-folds/train_5folds.csv'
sample_sub_file_path = os.path.join(csv_dir, 'sample_submission.csv')

print(f'Train file: {train_file_path}')
print(f'Train file: {sample_sub_file_path}')
# Out:
# Train file: ./input/pawpular-folds/train_5folds.csv
# Train file: ./input/pertfinder-pawpularity-score/sample_submission.csv

# %%
train_df = pd.read_csv(train_file_path)
test_df = pd.read_csv(sample_sub_file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3698/3381110351.py in <module>
# ----> 1 train_df = pd.read_csv(train_file_path)
#       2 test_df = pd.read_csv(sample_sub_file_path)
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
# ...
